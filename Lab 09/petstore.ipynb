# %%
class petstore: # creating a class named petstore
    def __init__(self):
        self.pets={
            "dog":[],
            "cat":[]
        } # creating 2 lists in the dictionary
        
        
    def add_details(self,type,breed,age,gender,price):
            self.pets[type].append({
                "breed":breed,
                "age":age,
                "gender":gender,
                "price":price,
            })  # adding details about the pet by froming a dictionary for the same

            # if type=="dogs":
            #     self.pets["dogs"].append(details)
            # elif type=="cats":
            #     self.pets["cats"].append(details)

    def search(self,type):
        type=input("enter the type of pet")
        if type in self.pets:
            for item in self.pets[type]:
                print(item)  # searching for the pet

        # for item in self.pets[type]:
        #     for i in self.pets.values(i):
        #         if i == type:
        #             print("true")
        #         else:
        #             print("false")
    # def sell(self,type):
    #     type=input("enter the type of pet you want ")
    #     for item in self.pets[type]:
    #         for i in self.pets.values(i):
    #             print(self.pets[item]['price'][i])
    #             self.pets["dogs"].pop(i)

    def print(self):
        print(self.pets) # printing all the pets

def collectInput():
    breed = input("Enter the breed ")
    age = input("Enter age ")
    gender = input("Enter gender")
    price = input("enter the price ")
    return breed, age, gender, price # collecting the pets input

pets=petstore() # creating an object for the class

# creating a menu driven program to implement the different functions used in the class

while True:
    print("1. add a dog")
    print("2. add a cat")
    print("3. search the pet")
    print("4. print the pets")
    print("5. exit")

    choice=input("enter your choice")
    if choice=="1":
        breed,age,gender,price= collectInput()
        pets.add_details("dog",breed,age,gender,price)
    elif choice=="2":
        breed,age,gender,price= collectInput()
        pets.add_details("cat",breed,age,gender,price)
    elif choice=="3":
        type=input("enter the type")
        pets.search(type)
    elif choice=="4":
        pets.print()
    elif choice=="5":
        break
# Out:
# 1. add a dog
# 2. add a cat
# 3. search the pet
# 4. print the pets
# 5. exit
# 1. add a dog
# 2. add a cat
# 3. search the pet
# 4. print the pets
# 5. exit
# 1. add a dog
# 2. add a cat
# 3. search the pet
# 4. print the pets
# 5. exit
# {'breed': 'husky', 'age': '5', 'gender': 'male', 'price': '5000'}
# 1. add a dog
# 2. add a cat
# 3. search the pet
# 4. print the pets
# 5. exit
# {'dog': [{'breed': 'husky', 'age': '5', 'gender': 'male', 'price': '5000'}], 'cat': [{'breed': 'persian', 'age': '3', 'gender': 'female', 'price': '3000'}]}
# 1. add a dog
# 2. add a cat
# 3. search the pet
# 4. print the pets
# 5. exit
