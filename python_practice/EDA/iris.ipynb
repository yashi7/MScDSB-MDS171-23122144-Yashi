# %%
import numpy as np
import pandas as pd

# %%
flower=pd.read_csv("IRIS.csv")

# %%
type(flower)
# Out:
# pandas.core.frame.DataFrame

# %%
flower.shape
# Out:
# (150, 5)

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
flower.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
flower.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
flower.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
pip install seaborn
# Out:
# ...
#                                               0.0/294.6 kB ? eta -:--:--
#      ----                                    30.7/294.6 kB 1.4 MB/s eta 0:00:01
#      ----                                    30.7/294.6 kB 1.4 MB/s eta 0:00:01
#      ----                                    30.7/294.6 kB 1.4 MB/s eta 0:00:01
#      -------                               61.4/294.6 kB 328.2 kB/s eta 0:00:01
#      -------                               61.4/294.6 kB 328.2 kB/s eta 0:00:01
#      -------                               61.4/294.6 kB 328.2 kB/s eta 0:00:01
#      -----------                           92.2/294.6 kB 276.8 kB/s eta 0:00:01
#      ---------------                      122.9/294.6 kB 328.4 kB/s eta 0:00:01
#      --------------------                 163.8/294.6 kB 378.3 kB/s eta 0:00:01
#      --------------------                 163.8/294.6 kB 378.3 kB/s eta 0:00:01
#      ---------------------                174.1/294.6 kB 318.1 kB/s eta 0:00:01
# ...

# %%
import seaborn as sns

# %%
flower=pd.read_csv("IRIS.csv")

# %%
sns.catplot(data=flower, x="sepal_length", y="petal_length")

# %%
dataset=pd.read_csv("Blank Quiz.csv")

# %%
dataset.describe()
# Out:
#        STAFF SERVICE  Travel Convenience   \
# count     223.000000           223.000000
# mean        3.488789             3.076233
# std         1.240681             1.192514
# min         1.000000             1.000000
# 25%         3.000000             2.000000
# 50%         4.000000             3.000000
# 75%         5.000000             4.000000
# max         5.000000             5.000000
#
#        How would you Rate the activities and attraction  Worth of Money  \
# count                                        223.000000      223.000000
# mean                                           3.686099        3.363229
# std                                            1.158647        0.971621
# min                                            1.000000        1.000000
# 25%                                            3.000000        3.000000
# 50%                                            4.000000        3.000000
# 75%                                            5.000000        4.000000
# ...

# %%
dataset.head()
# Out:
#                         Timestamp AGE  GENDER CITY YOU ARE FROM?  \
# 0  2023/10/10 6:40:25 PM GMT+5:30  24  FEMALE              Delhi
# 1  2023/10/10 6:42:51 PM GMT+5:30  22    MALE            KOLKATA
# 2  2023/10/10 6:52:16 PM GMT+5:30  21  FEMALE             meerut
# 3  2023/10/10 6:56:37 PM GMT+5:30  21  FEMALE     Pathanamthitta
# 4  2023/10/10 7:03:07 PM GMT+5:30  18  FEMALE            Nagpur
#
#   PURPOSE OF VISIT CATEGORY OF VISITORS WHERE DID YOU STAY?  \
# 0          Student                 Solo        Celebrations
# 1  Vacation;Others               Couple              Ekaant
# 2          Student                 Solo        Celebrations
# 3          Student               Family        Picnic House
# 4          Student                 Solo        Celebrations
#
#   HOTEL CHARGES /DAY                                  AMENITIES YOU GOT  \
# 0          2000-3000                    Room service and Wifi;Game room
# ...

# %%
sns.catplot(data=dataset, y="PURPOSE OF VISIT",x="GENDER",hue='CATEGORY OF VISITORS',kind="box")

# %%
#load a csv,set new col names
#rename col names (1 col,multiple col)
#load the dataset set one col as index
#split your data into multiple files with respect to rows and cols
#load the different files to different data frames and merge them to final file

# %%
import pandas as pd

# %%
vacation=pd.read_csv("Blank Quiz.csv")

# %%
vac=vacation.rename(columns = {'AGE':'HOW OLD','CITY YOU ARE FROM?':'CITY'})

# %%
vac.set_index('HOW OLD')
# Out:
#                                        Timestamp  GENDER            CITY  \
# HOW OLD
# 24                2023/10/10 6:40:25 PM GMT+5:30  FEMALE           Delhi
# 22                2023/10/10 6:42:51 PM GMT+5:30    MALE         KOLKATA
# 21                2023/10/10 6:52:16 PM GMT+5:30  FEMALE          meerut
# 21                2023/10/10 6:56:37 PM GMT+5:30  FEMALE  Pathanamthitta
# 18                2023/10/10 7:03:07 PM GMT+5:30  FEMALE         Nagpur
# ...                                          ...     ...             ...
# 21               2023/10/16 12:09:33 PM GMT+5:30  FEMALE        Gurgaon
# 21               2023/10/16 12:12:42 PM GMT+5:30    MALE           Sikar
# 21                2023/10/16 4:57:08 PM GMT+5:30  FEMALE       New Delhi
# Dev Madhusudan    2023/10/16 5:41:58 PM GMT+5:30    MALE       Faridabad
# 21               2023/10/16 10:13:30 PM GMT+5:30    MALE         Kolkata
#
#                 PURPOSE OF VISIT CATEGORY OF VISITORS WHERE DID YOU STAY?  \
# ...

# %%
af=vac.loc[:,'STAFF SERVICE':'Activities']

# %%
bf=vac.loc[:,'HOW OLD':'CITY']

# %%
vac.dropna()
# Out:
#                            Timestamp HOW OLD  GENDER      CITY  \
# 1     2023/10/10 6:42:51 PM GMT+5:30      22    MALE   KOLKATA
# 2     2023/10/10 6:52:16 PM GMT+5:30      21  FEMALE    meerut
# 4     2023/10/10 7:03:07 PM GMT+5:30      18  FEMALE   Nagpur
# 5     2023/10/10 7:04:43 PM GMT+5:30      21  FEMALE   Kolkata
# 8     2023/10/10 7:14:06 PM GMT+5:30      20  FEMALE   Kolkata
# ..                               ...     ...     ...       ...
# 215   2023/10/15 8:21:16 PM GMT+5:30      19    MALE       Hyd
# 217   2023/10/15 8:21:34 PM GMT+5:30      21    MALE  Durgapur
# 218  2023/10/16 12:09:33 PM GMT+5:30      21  FEMALE  Gurgaon
# 219  2023/10/16 12:12:42 PM GMT+5:30      21    MALE     Sikar
# 222  2023/10/16 10:13:30 PM GMT+5:30      21    MALE   Kolkata
#
#     PURPOSE OF VISIT CATEGORY OF VISITORS WHERE DID YOU STAY?  \
# 1    Vacation;Others               Couple              Ekaant
# 2            Student                 Solo        Celebrations
# ...
